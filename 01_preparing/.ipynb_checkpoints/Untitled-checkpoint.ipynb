# %%
import pandas as pd

# %%
at2000 = pd.read_csv("../data/cleaned/attribute2000.csv")
at2001 = pd.read_csv("../data/cleaned/attribute2001.csv")
at2002 = pd.read_csv("../data/cleaned/attribute2002.csv")
at2003 = pd.read_csv("../data/cleaned/attribute2003.csv")
at2004 = pd.read_csv("../data/cleaned/attribute2004.csv")
at2005 = pd.read_csv("../data/cleaned/attribute2005.csv")
at2006 = pd.read_csv("../data/cleaned/attribute2006.csv")
at2007 = pd.read_csv("../data/cleaned/attribute2007.csv")
at2008 = pd.read_csv("../data/cleaned/attribute2008.csv")
at2009 = pd.read_csv("../data/cleaned/attribute2009.csv")
at2010 = pd.read_csv("../data/cleaned/attribute2010.csv")
at2011 = pd.read_csv("../data/cleaned/attribute2011.csv")
at2012 = pd.read_csv("../data/cleaned/attribute2012.csv")
at2013 = pd.read_csv("../data/cleaned/attribute2013.csv")
at2014 = pd.read_csv("../data/cleaned/attribute2014.csv")
at2015 = pd.read_csv("../data/cleaned/attribute2015.csv")
at2016 = pd.read_csv("../data/cleaned/attribute2016.csv")
at2017 = pd.read_csv("../data/cleaned/attribute2017.csv")
at2018 = pd.read_csv("../data/cleaned/attribute2018.csv")
at2019 = pd.read_csv("../data/cleaned/attribute2019.csv")
at2020 = pd.read_csv("../data/cleaned/attribute2020.csv")
node_fix = pd.read_csv("../data/cleaned/nodal_fixed.csv")

# %%
long = pd.concat([at2000, at2001, at2002, at2003, at2004, at2005, at2006, at2007, at2008,at2009, at2010, at2011, at2012, at2013, at2014, at2015, at2016, at2017, at2018, at2019, at2020], axis = 0)

# %%
long.head(2)
# Out:
#    Unnamed: 0 iso_o   sigma_cp  rank_cp  cp    country  TIME_PERIOD  LTE  \
# 0           1   ARG  394899959       40   0  Argentina         2000    0
# 1           2   AUS  982626724       24   0  Australia         2000    0
#
#     internet   gdp_pct  ...  D_log_gdp_pct  D_internet  landlocked  continent  \
# 0   7.040000  10631.65  ...      -0.019252        3.76           0    America
# 1  46.799999  45859.52  ...       0.027021        6.00           0    Pacific
#
#          lat      lon  langoff_1  colonizer1  \
# 0 -34.666668  -58.500    Spanish         ESP
# 1 -35.299999  149.133    English         GBR
#
#                             category development
# 0  Emerging and Developing Economies           0
# 1                 Advanced Economies           1
#
# [2 rows x 22 columns]

# %%
print(long['iso_o'].nunique())
print(long['TIME_PERIOD'].nunique())
print(long['TIME_PERIOD'].unique())
# Out:
# 74
# 21
# [2000 2001 2002 2003 2004 2005 2006 2007 2008 2009 2010 2011 2012 2013
#  2014 2015 2016 2017 2018 2019 2020]

# %%
missing = long.isna().sum()
missing
# Out:
# Unnamed: 0         0
# iso_o              0
# sigma_cp           0
# rank_cp            0
# cp                 0
# country            0
# TIME_PERIOD        0
# LTE                0
# internet           0
# gdp_pct            0
# schooling          0
# log_gdp_pct        0
# D_log_gdp_pct      0
# D_internet         0
# landlocked         0
# continent          0
# lat                0
# lon                0
# langoff_1          0
# colonizer1       420
# category           0
# development        0
# dtype: int64

# %%
long = long.drop(columns = ['colonizer1', 'langoff_1'])

# %%
long_sorted = long.sort_values(['iso_o', 'country', 'TIME_PERIOD']).reset_index(drop= True)

# %% [markdown]
# ### RTA

# %%
rta = pd.read_csv("../data/cleaned/rta_long.csv")

# %%
rta
# Out:
#        iso_o iso_d  TIME_PERIOD  rta
# 0        ARG   AUS         2000    0
# 1        ARG   AUS         2001    0
# 2        ARG   AUS         2002    0
# 3        ARG   AUS         2003    0
# 4        ARG   AUS         2004    0
# ...      ...   ...          ...  ...
# 113437   ZAF   VNM         2016    0
# 113438   ZAF   VNM         2017    0
# 113439   ZAF   VNM         2018    0
# 113440   ZAF   VNM         2019    0
# 113441   ZAF   VNM         2020    0
#
# [113442 rows x 4 columns]

# %%
print(rta['iso_o'].nunique())
print(rta['iso_d'].nunique())
# Out:
# 74
# 74

# %%
co2 = pd.read_csv("../data/cleaned/emission_trade2000_2020.csv")

# %%
co2.head(3)
# Out:
#   iso_o iso_d  TIME_PERIOD    co2  rta
# 0   AUS   ARG         2000  0.393    0
# 1   AUS   ARG         2001  0.474    0
# 2   AUS   ARG         2002  0.282    0

# %% [markdown]
# # merging RTA and co2

# %%
co2 = co2.merge(rta, on = ['iso_o', 'iso_d', 'TIME_PERIOD'], how = 'left')

# %%
co2 = co2.rename(columns = {'OBS_VALUE': 'co2'})

# %%
assert set(co2['iso_o'].unique()) == set(long_sorted['iso_o'].unique())

# %%
assert set(co2['TIME_PERIOD'].unique()) == set(long_sorted['TIME_PERIOD'].unique())

# %%
long_sorted.shape
# Out:
# (1554, 20)

# %%
co2.shape
# Out:
# (113442, 5)

# %%
co2 = co2.reset_index(drop = True)

# %%
(74*74-74)*21
# Out:
# 113442

# %%
merged = co2.merge(long_sorted, on = ['iso_o', 'TIME_PERIOD'], how = 'left')

# %%
merged.columns
# Out:
# Index(['iso_o', 'iso_d', 'TIME_PERIOD', 'co2', 'rta', 'sigma_cp', 'rank_cp',
#        'cp', 'country', 'LTE', 'internet', 'gdp_pct', 'schooling',
#        'log_gdp_pct', 'D_log_gdp_pct', 'D_internet', 'landlocked', 'continent',
#        'lat', 'lon', 'category', 'development'],
#       dtype='object')

# %%
merged = merged.drop(columns= 'Unnamed: 0')

# %%
merged = merged.drop(columns= ['category', 'lat', 'lon'])

# %%
merged.head()
# Out:
#   iso_o iso_d  TIME_PERIOD    co2  rta    sigma_cp  rank_cp  cp    country  \
# 0   AUS   ARG         2000  0.393    0   982626724       24   0  Australia
# 1   AUS   ARG         2001  0.474    0   924830980       24   0  Australia
# 2   AUS   ARG         2002  0.282    0   989709238       24   0  Australia
# 3   AUS   ARG         2003  0.363    0  1126782244       27   0  Australia
# 4   AUS   ARG         2004  0.156    0  1348746428       26   0  Australia
#
#    LTE   internet    gdp_pct  schooling  log_gdp_pct  D_log_gdp_pct  \
# 0    0  46.799999  45859.520  20.779854    10.733338       0.027021
# 1    0  52.700001  46191.309  20.944376    10.740547       0.007209
# 2    0  23.694054  47486.281  21.108898    10.768196       0.027649
# 3    0  27.593699  48394.129  21.273420    10.787134       0.018938
# 4    0  31.496302  49902.020  21.437941    10.817817       0.030683
#
#    D_internet  landlocked continent  development
# 0    6.000000           0   Pacific            1
# 1    5.900002           0   Pacific            1
# 2  -29.005947           0   Pacific            1
# 3    3.899645           0   Pacific            1
# 4    3.902603           0   Pacific            1

# %%
country_list = co2['iso_o'].unique()
print(len(country_list))
years = list(range(2000, 2021))
panel_df = pd.MultiIndex.from_product([country_list, country_list, years], names=['iso_o', 'iso_d', 'TIME_PERIOD'])
panel_df_blank = panel_df.to_frame(index=False)
# Out:
# 74

# %%
panel_df_blank = panel_df_blank[panel_df_blank['iso_o'] != panel_df_blank['iso_d']]

# %%
print(panel_df_blank['iso_o'].nunique())
print(panel_df_blank['iso_d'].nunique())
print(panel_df_blank['TIME_PERIOD'].nunique())
print(panel_df_blank.groupby(['iso_o','iso_d']).ngroups)
# Out:
# 74
# 74
# 21
# 5402

# %%
(74*74-74)*21
# Out:
# 113442

# %%
panel_df_blank.shape[0]
# Out:
# 113442

# %%
co2_panel = panel_df_blank.merge(merged, on = ['iso_o', 'iso_d', 'TIME_PERIOD'], how = 'left')

# %%
print(co2_panel['iso_o'].nunique())
print(co2_panel['iso_d'].nunique())
print(co2_panel['TIME_PERIOD'].nunique())
print(co2_panel.groupby(['iso_o','iso_d']).ngroups)
# Out:
# 74
# 74
# 21
# 5402

# %%
co2_panel.head()
# Out:
#   iso_o iso_d  TIME_PERIOD    co2  rta    sigma_cp  rank_cp  cp    country  \
# 0   AUS   AUT         2000  0.082    0   982626724       24   0  Australia
# 1   AUS   AUT         2001  0.099    0   924830980       24   0  Australia
# 2   AUS   AUT         2002  0.098    0   989709238       24   0  Australia
# 3   AUS   AUT         2003  0.087    0  1126782244       27   0  Australia
# 4   AUS   AUT         2004  0.103    0  1348746428       26   0  Australia
#
#    LTE   internet    gdp_pct  schooling  log_gdp_pct  D_log_gdp_pct  \
# 0    0  46.799999  45859.520  20.779854    10.733338       0.027021
# 1    0  52.700001  46191.309  20.944376    10.740547       0.007209
# 2    0  23.694054  47486.281  21.108898    10.768196       0.027649
# 3    0  27.593699  48394.129  21.273420    10.787134       0.018938
# 4    0  31.496302  49902.020  21.437941    10.817817       0.030683
#
#    D_internet  landlocked continent  development
# 0    6.000000           0   Pacific            1
# 1    5.900002           0   Pacific            1
# 2  -29.005947           0   Pacific            1
# 3    3.899645           0   Pacific            1
# 4    3.902603           0   Pacific            1

# %%
partner_attributes = co2_panel.copy()

# %%
partner_attributes
# Out:
#        iso_o iso_d  TIME_PERIOD    co2  rta    sigma_cp  rank_cp  cp  \
# 0        AUS   AUT         2000  0.082    0   982626724       24   0
# 1        AUS   AUT         2001  0.099    0   924830980       24   0
# 2        AUS   AUT         2002  0.098    0   989709238       24   0
# 3        AUS   AUT         2003  0.087    0  1126782244       27   0
# 4        AUS   AUT         2004  0.103    0  1348746428       26   0
# ...      ...   ...          ...    ...  ...         ...      ...  ..
# 113437   ARG   ZAF         2016  0.547    1   930226612       41   0
# 113438   ARG   ZAF         2017  0.323    1  1012867359       42   0
# 113439   ARG   ZAF         2018  0.529    1  1008652952       43   0
# 113440   ARG   ZAF         2019  0.737    1   911011007       41   0
# 113441   ARG   ZAF         2020  0.336    1   783511988       41   0
#
#           country  LTE   internet    gdp_pct  schooling  log_gdp_pct  \
# 0       Australia    0  46.799999  45859.520  20.779854    10.733338
# 1       Australia    0  52.700001  46191.309  20.944376    10.740547
# 2       Australia    0  23.694054  47486.281  21.108898    10.768196
# 3       Australia    0  27.593699  48394.129  21.273420    10.787134
# 4       Australia    0  31.496302  49902.020  21.437941    10.817817
# ...           ...  ...        ...        ...        ...          ...
# 113437  Argentina    1  71.000000  13265.890  17.857731     9.492951
# 113438  Argentina    1  74.300003  13520.110  17.842970     9.511933
# 113439  Argentina    1  77.699997  13058.330  17.857821     9.477181
# 113440  Argentina    1  79.900002  12706.400  18.086370     9.449862
# 113441  Argentina    1  85.500000  11393.050  18.361160     9.340758
#
#         D_log_gdp_pct  D_internet  landlocked continent  development
# 0            0.027021    6.000000           0   Pacific            1
# 1            0.007209    5.900002           0   Pacific            1
# 2            0.027649  -29.005947           0   Pacific            1
# 3            0.018938    3.899645           0   Pacific            1
# 4            0.030683    3.902603           0   Pacific            1
# ...               ...         ...         ...       ...          ...
# 113437      -0.030712    3.000000           0   America            0
# 113438       0.018982    3.300003           0   America            0
# 113439      -0.034752    3.399994           0   America            0
# 113440      -0.027320    2.200005           0   America            0
# 113441      -0.109103    5.599998           0   America            0
#
# [113442 rows x 19 columns]

# %%
partner_attributes = partner_attributes.drop(columns = ['iso_d', 'co2', 'rta'])

# %%
partner_attributes = partner_attributes.rename(columns = {'iso_o': 'iso_d'})
partner_attributes = partner_attributes.rename(columns = {'country': 'country_d'})
partner_attributes = partner_attributes.rename(columns = {'gdp_pct': 'gdp_pct_d'})
partner_attributes = partner_attributes.rename(columns = {'log_gdp_pct': 'log_gdp_pct_d'})
partner_attributes = partner_attributes.rename(columns = {'D_log_gdp_pct': 'D_log_gdp_pct_d'})
partner_attributes = partner_attributes.rename(columns = {'internet': 'internet_d'})
partner_attributes = partner_attributes.rename(columns = {'D_internet': 'D_internet_d'})
partner_attributes = partner_attributes.rename(columns = {'schooling': 'schooling_d'})
partner_attributes = partner_attributes.rename(columns = {'LTE': 'LTE_d'})
partner_attributes = partner_attributes.rename(columns = {'sigma_cp': 'sigma_cp_d'})
partner_attributes = partner_attributes.rename(columns = {'rank_cp': 'rank_cp_d'})
partner_attributes = partner_attributes.rename(columns = {'cp': 'cp_d'})
partner_attributes = partner_attributes.rename(columns = {'landlocked': 'landlocked_d'})
partner_attributes = partner_attributes.rename(columns = {'continent': 'continent_d'})
partner_attributes = partner_attributes.rename(columns = {'development': 'development_d'})

# %%
search_duplicate_row = ['iso_d', 'TIME_PERIOD']
partner_attributes_duplicate = partner_attributes.drop_duplicates(subset = search_duplicate_row,  keep = 'last')

# %%
partner_attributes_duplicate
# Out:
#        iso_d  TIME_PERIOD  sigma_cp_d  rank_cp_d  cp_d  country_d  LTE_d  \
# 1512     AUS         2000   982626724         24     0  Australia      0
# 1513     AUS         2001   924830980         24     0  Australia      0
# 1514     AUS         2002   989709238         24     0  Australia      0
# 1515     AUS         2003  1126782244         27     0  Australia      0
# 1516     AUS         2004  1348746428         26     0  Australia      0
# ...      ...          ...         ...        ...   ...        ...    ...
# 113437   ARG         2016   930226612         41     0  Argentina      1
# 113438   ARG         2017  1012867359         42     0  Argentina      1
# 113439   ARG         2018  1008652952         43     0  Argentina      1
# 113440   ARG         2019   911011007         41     0  Argentina      1
# 113441   ARG         2020   783511988         41     0  Argentina      1
#
#         internet_d  gdp_pct_d  schooling_d  log_gdp_pct_d  D_log_gdp_pct_d  \
# 1512     46.799999  45859.520    20.779854      10.733338         0.027021
# 1513     52.700001  46191.309    20.944376      10.740547         0.007209
# 1514     23.694054  47486.281    21.108898      10.768196         0.027649
# 1515     27.593699  48394.129    21.273420      10.787134         0.018938
# 1516     31.496302  49902.020    21.437941      10.817817         0.030683
# ...            ...        ...          ...            ...              ...
# 113437   71.000000  13265.890    17.857731       9.492951        -0.030712
# 113438   74.300003  13520.110    17.842970       9.511933         0.018982
# 113439   77.699997  13058.330    17.857821       9.477181        -0.034752
# 113440   79.900002  12706.400    18.086370       9.449862        -0.027320
# 113441   85.500000  11393.050    18.361160       9.340758        -0.109103
#
#         D_internet_d  landlocked_d continent_d  development_d
# 1512        6.000000             0     Pacific              1
# 1513        5.900002             0     Pacific              1
# 1514      -29.005947             0     Pacific              1
# 1515        3.899645             0     Pacific              1
# 1516        3.902603             0     Pacific              1
# ...              ...           ...         ...            ...
# 113437      3.000000             0     America              0
# 113438      3.300003             0     America              0
# 113439      3.399994             0     America              0
# 113440      2.200005             0     America              0
# 113441      5.599998             0     America              0
#
# [1554 rows x 16 columns]

# %%
panel = co2_panel.merge(partner_attributes_duplicate, on = ['iso_d', 'TIME_PERIOD'], how = 'left')

# %%
panel.columns
# Out:
# Index(['iso_o', 'iso_d', 'TIME_PERIOD', 'co2', 'rta', 'sigma_cp', 'rank_cp',
#        'cp', 'country', 'LTE', 'internet', 'gdp_pct', 'schooling',
#        'log_gdp_pct', 'D_log_gdp_pct', 'D_internet', 'landlocked', 'continent',
#        'development', 'sigma_cp_d', 'rank_cp_d', 'cp_d', 'country_d', 'LTE_d',
#        'internet_d', 'gdp_pct_d', 'schooling_d', 'log_gdp_pct_d',
#        'D_log_gdp_pct_d', 'D_internet_d', 'landlocked_d', 'continent_d',
#        'development_d'],
#       dtype='object')

# %%
panel= panel.reset_index(drop=True)

# %%
panel.shape
# Out:
# (113442, 33)

# %%
panel.head(10)
# Out:
#   iso_o iso_d  TIME_PERIOD    co2  rta    sigma_cp  rank_cp  cp    country  \
# 0   AUS   AUT         2000  0.082    0   982626724       24   0  Australia
# 1   AUS   AUT         2001  0.099    0   924830980       24   0  Australia
# 2   AUS   AUT         2002  0.098    0   989709238       24   0  Australia
# 3   AUS   AUT         2003  0.087    0  1126782244       27   0  Australia
# 4   AUS   AUT         2004  0.103    0  1348746428       26   0  Australia
# 5   AUS   AUT         2005  0.092    0  1592539136       26   0  Australia
# 6   AUS   AUT         2006  0.123    0  1808489246       25   0  Australia
# 7   AUS   AUT         2007  0.125    0  2086947935       24   0  Australia
# 8   AUS   AUT         2008  0.095    0  2626806281       21   0  Australia
# 9   AUS   AUT         2009  0.085    0  2199133084       20   0  Australia
#
#    LTE  ...  LTE_d  internet_d  gdp_pct_d  schooling_d  log_gdp_pct_d  \
# 0    0  ...      0   33.700001  38571.090    15.232909      10.560258
# 1    0  ...      0   39.200001  38929.750    15.307923      10.569514
# 2    0  ...      0   36.599998  39313.719    15.382937      10.579329
# 3    0  ...      0   42.700001  39569.289    15.457952      10.585809
# 4    0  ...      0   54.299999  40333.328    15.532967      10.604934
# 5    0  ...      0   58.000000  40989.012    15.607981      10.621059
# 6    0  ...      0   63.599998  42120.160    15.682996      10.648282
# 7    0  ...      0   69.400002  43568.828    15.758010      10.682097
# 8    0  ...      0   72.900002  44063.859    15.861150      10.693396
# 9    0  ...      0   73.500000  42372.480    15.866870      10.654254
#
#    D_log_gdp_pct_d  D_internet_d landlocked_d  continent_d  development_d
# 0         0.028992     10.700001            1       Europe              1
# 1         0.009256      5.500000            1       Europe              1
# 2         0.009814     -2.600002            1       Europe              1
# 3         0.006480      6.100002            1       Europe              1
# 4         0.019125     11.599998            1       Europe              1
# 5         0.016126      3.700001            1       Europe              1
# 6         0.027223      5.599998            1       Europe              1
# 7         0.033815      5.800003            1       Europe              1
# 8         0.011298      3.500000            1       Europe              1
# 9        -0.039142      0.599998            1       Europe              1
#
# [10 rows x 33 columns]

# %%
panel.to_csv("../data/cleaned/panel.csv", encoding = 'utf-8', index = False)
